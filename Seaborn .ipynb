# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
# %matplotlib inline

# %%
shsat = pd.read_csv('C:\\Users\\STEVEN\\Documents\\Thinkful\\SHSAT.csv')
df = pd.read_csv('C:\\Users\\STEVEN\\Documents\\Thinkful\\2016 School Explorer.csv')

# %%
df.shape
# Out:
# (1272, 161)

# %%
shsat.shape
# Out:
# (140, 7)

# %%
df.head(3)
# Out:
#   Adjusted Grade New? Other Location Code in LCGMS                School Name  \
# 0            NaN  NaN                          NaN  P.S. 015 ROBERTO CLEMENTE
# 1            NaN  NaN                          NaN        P.S. 019 ASHER LEVY
# 2            NaN  NaN                          NaN       P.S. 020 ANNA SILVER
#
#        SED Code Location Code  District   Latitude  Longitude  \
# 0  310100010015        01M015         1  40.721834 -73.978766
# 1  310100010019        01M019         1  40.729892 -73.984231
# 2  310100010020        01M020         1  40.721274 -73.986315
#
#                     Address (Full)  \
# 0  333 E 4TH ST NEW YORK, NY 10009
# 1   185 1ST AVE NEW YORK, NY 10003
# 2  166 ESSEX ST NEW YORK, NY 10002
#
#                       ...                       \
# 0                     ...
# 1                     ...
# 2                     ...
#
#   Grade 8 Math - All Students Tested  Grade 8 Math 4s - All Students  \
# ...

# %%
def p2f(x):
    return float(x.strip('%'))/100

df['Percent of Students Chronically Absent']=df['Percent of Students Chronically Absent'].astype(str).apply(p2f)
df['Rigorous Instruction %'] = df['Rigorous Instruction %'].astype(str).apply(p2f)
df['Collaborative Teachers %'] = df['Collaborative Teachers %'].astype(str).apply(p2f)
df['Supportive Environment %'] = df['Supportive Environment %'].astype(str).apply(p2f)
df['Effective School Leadership %'] = df['Effective School Leadership %'].astype(str).apply(p2f)
df['Strong Family-Community Ties %'] = df['Strong Family-Community Ties %'].astype(str).apply(p2f)
df['Trust %'] = df['Trust %'].astype(str).apply(p2f)
df['Student Attendance Rate'] = df['Student Attendance Rate'].astype(str).apply(p2f)
df['Percent Asian'] = df['Percent Asian'].astype(str).apply(p2f)
df['Percent Black'] = df['Percent Black'].astype(str).apply(p2f)
df['Percent Hispanic'] = df['Percent Hispanic'].astype(str).apply(p2f)
df['Percent White'] = df['Percent White'].astype(str).apply(p2f)

# %%
#One variable four plots
#1 plot
sns.barplot(df['Percent Asian'])

# %%
#2 Plot
sns.boxplot(df['Percent Asian'])

# %%
#3 Plot
sns.distplot(df['Percent Asian'])
# Out:
# c:\users\steven\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#4 Plot
sns.set(style='ticks')
sns.boxplot(data=df['Percent Asian'], palette='PRGn')
sns.despine(offset=10, trim=True)

# %%
#Two continuous variables 3 different ways: Black percentages vs. Hispanic
#1
grid = sns.JointGrid(df['Percent Hispanic'], df['Percent Black'], space=0, size=6, ratio=50)
grid.plot_joint(plt.scatter, color='g')
grid.plot_marginals(sns.rugplot, height=1, color='g')

# %%
sns.set(style='ticks')
x = df['Percent Hispanic']
y = df['Percent Black']
sns.jointplot(x, y, kind='hex')
# Out:
# c:\users\steven\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# c:\users\steven\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#3
g= sns.jointplot(df['Percent Hispanic'], df['Percent Black'], kind='kde')

# %%
#One continuous vs. one categorical variable. 6 graphs
#Categorical variable will be community school
community_school = df[df["Community School?"]=='Yes']
no_community = df[df['Community School?']=='No']

# %%
#1&2
plt.subplot(1,2,1)
sns.set(style='ticks')
sns.boxplot(data=community_school['Percent Hispanic'], palette='PRGn')
sns.despine(offset=10, trim=True)

plt.subplot(1,2,2)
sns.set(style='ticks')
sns.boxplot(no_community['Percent Hispanic'], palette='PRGn')
sns.despine(offset=10, trim=True)

# %%
#3&4
plt.subplot(1,2,1)
sns.distplot(no_community['Percent White'], kde=False, color='b')

plt.subplot(1,2,2)
sns.distplot(community_school['Percent White'], kde=False, color='g')
# Out:
# c:\users\steven\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# c:\users\steven\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#5 & 6
plt.subplot(1,2,1)
sns.stripplot(community_school['Percent Asian'])

plt.subplot(1,2,2)
sns.stripplot(no_community['Percent Asian'])
